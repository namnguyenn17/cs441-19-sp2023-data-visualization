# %%
import pandas as pd
import folium

# %%
location = "https://data.smartdublin.ie/dataset/33ec9fe2-4957-4e9a-ab55-c5e917c7a9ab/resource/2dec86ed-76ed-47a3-ae28-646db5c5b965/download/dublin.csv"
bike_station_locations = pd.read_csv(location)

# %%
# Generate 10 random indices between 1 and the number of rows in the dataset
random_indices = [randint(1, len(df)) for i in range(11)]

# %%
bike_station_locations
# Out:
#      Number                    Name                 Address   Latitude  \
# 0        42        SMITHFIELD NORTH        Smithfield North  53.349562
# 1        30    PARNELL SQUARE NORTH    Parnell Square North  53.353462
# 2        54          CLONMEL STREET          Clonmel Street  53.336021
# 3       108           AVONDALE ROAD           Avondale Road  53.359405
# 4        56      MOUNT STREET LOWER      Mount Street Lower  53.337960
# ..      ...                     ...                     ...        ...
# 105      39          WILTON TERRACE          Wilton Terrace  53.332383
# 106      83              EMMET ROAD              Emmet Road  53.340714
# 107      92  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)  53.347802
# 108      21   LEINSTER STREET SOUTH   Leinster Street South  53.342180
# 109      88         BLACKHALL PLACE         Blackhall Place  53.348800
#
#      Longitude
# 0    -6.278198
# 1    -6.265305
# 2    -6.262980
# 3    -6.276142
# 4    -6.241530
# ..         ...
# 105  -6.252717
# 106  -6.308191
# 107  -6.292432
# 108  -6.254485
# 109  -6.281637
#
# [110 rows x 5 columns]

# %%
# Keeping only necessary columns
bike_station_locations = bike_station_locations[["Latitude", "Longitude", "Name"]]

# %%
# Creating the map and adding points to it
map = folium.Map(location=[bike_station_locations.Latitude.mean(), bike_station_locations.Longitude.mean()], zoom_start=14, control_scale=True)

for index, location_info in bike_station_locations.iterrows():
    folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Name"]).add_to(map)

# %%
# Displaying the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d02a1671f09ad1cb4fb654cee403e4ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d02a1671f09ad1cb4fb654cee403e4ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d02a1671f09ad1cb4fb654cee403e4ec = L.map(
#                 &quot;map_d02a1671f09ad1cb4fb654cee403e4ec&quot;,
#                 {
#                     center: [53.34549189090908, -6.264740490909091],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d02a1671f09ad1cb4fb654cee403e4ec);
#
#
#
#
#
#             var tile_layer_9204571504b6e484e8e44da4167013a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d02a1671f09ad1cb4fb654cee403e4ec);
#
#
#             var marker_b82cbb86c7cf77f2f9d4c653a317dd92 = L.marker(
#                 [53.349562, -6.278198],
#                 {}
#             ).addTo(map_d02a1671f09ad1cb4fb654cee403e4ec);
#
#
#         var popup_b25b36abd6897aabcd73e3cbc4ea9fb4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18714c58a4935c0e6702aedbcba9aabc = $(`&lt;div id=&quot;html_18714c58a4935c0e6702aedbcba9aabc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SMITHFIELD NORTH&lt;/div&gt;`)[0];
#                 popup_b25b36abd6897aabcd73e3cbc4ea9fb4.setContent(html_18714c58a4935c0e6702aedbcba9aabc);
#
#
#
#         marker_b82cbb86c7cf77f2f9d4c653a317dd92.bindPopup(popup_b25b36abd6897aabcd73e3cbc4ea9fb4)
#         ;
#
#
#
#
#             var marker_7b9549a3fa4d79d2310f133bd745d86e = L.marker(
#                 [53.353462, -6.265305],
#                 {}
#             ).addTo(map_d02a1671f09ad1cb4fb654cee403e4ec);
#
#
#         var popup_e13604b5ab9df5259e659c8bfc286013 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_55a2f60a7cb30a4e37863302074896e5 = $(`&lt;div id=&quot;html_55a2f60a7cb30a4e37863302074896e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PARNELL SQUARE NORTH&lt;/div&gt;`)[0];
#                 popup_e13604b5ab9df5259e659c8bfc286013.setContent(html_55a2f60a7cb30a4e37863302074896e5);
#
#
#
#         marker_7b9549a3fa4d79d2310f133bd745d86e.bindPopup(popup_e13604b5ab9df5259e659c8bfc286013)
#         ;
#
#
#
#
#             var marker_db1674950a8120c6aedf348c37507c00 = L.marker(
#                 [53.336021, -6.26298],
#                 {}
#             ).addTo(map_d02a1671f09ad1cb4fb654cee403e4ec);
#
#
#         var popup_f3859b90ecb95313eb1632dbc04aac07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72fcab05b4f15f7751423b724e983a0c = $(`&lt;div id=&quot;html_72fcab05b4f15f7751423b724e983a0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CLONMEL STREET&lt;/div&gt;`)[0];
#                 popup_f3859b90ecb95313eb1632dbc04aac07.setContent(html_72fcab05b4f15f7751423b724e983a0c);
#
#
#
#         marker_db1674950a8120c6aedf348c37507c00.bindPopup(popup_f3859b90ecb95313eb1632dbc04aac07)
#         ;
#
#
#
#
#             var marker_94eaebd37fa5244a9c96dd142d10dd95 = L.marker(
#                 [53.359405, -6.276142],
#                 {}
#             ).addTo(map_d02a1671f09ad1cb4fb654cee403e4ec);
#
#
#         var popup_9574e143f4b828eee5cd5969d60f43a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d978820abb1c4baef38fa01ea2b120b = $(`&lt;div id=&quot;html_9d978820abb1c4baef38fa01ea2b120b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AVONDALE ROAD&lt;/div&gt;`)[0];
#                 popup_9574e143f4b828eee5cd5969d60f43a2.setContent(html_9d978820abb1c4baef38fa01ea2b120b);
#
#
#
#         marker_94eaebd37fa5244a9c96dd142d10dd95.bindPopup(popup_9574e143f4b828eee5cd5969d60f43a2)
#         ;
#
#
#
#
#             var marker_fc22c43db1782b395cc38c338fb644ef = L.marker(
#                 [53.33796, -6.24153],
#                 {}
#             ).addTo(map_d02a1671f09ad1cb4fb654cee403e4ec);
#
#
#         var popup_bcdc886b7fb0e667ea6cd2d5afbb85c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1b11acd375d5c8ab311d6f50bc0f534 = $(`&lt;div id=&quot;html_f1b11acd375d5c8ab311d6f50bc0f534&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MOUNT STREET LOWER&lt;/div&gt;`)[0];
#                 popup_bcdc886b7fb0e667ea6cd2d5afbb85c6.setContent(html_f1b11acd375d5c8ab311d6f50bc0f534);
#
#
#
#         marker_fc22c43db1782b395cc38c338fb644ef.bindPopup(popup_bcdc886b7fb0e667ea6cd2d5afbb85c6)
#         ;
#
#
#
#
#             var mar
